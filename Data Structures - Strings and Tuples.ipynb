# %%
#String Concatenation

# %%
SC="Hello "

# %%
print(SC)
# Out:
# Hello

# %%
SC1=input("Enter your name: ")
# Out:
# Enter your name: Sheela

# %%
print(SC + SC1)
# Out:
# Hello Sheela

# %%
SC2=", welcome to Python programming"

# %%
print(SC + SC1 + SC2)
# Out:
# Hello Sheela, welcome to Python programming

# %%
#String Slicing and Indexing

# %%
#Print the first character of the string

# %%
SC3 = "Hello Sheela, welcome to Python programming"

# %%
print(SC3[0])
# Out:
# H

# %%
#Print the last character of the string

# %%
print(SC3[-1])
# Out:
# g

# %%
#Print the first 5 characters of the string

# %%
print(SC3[0:5])
# Out:
# Hello

# %%
#Print the last 11 characters of the string.

# %%
print(SC3[-11:])
# Out:
# programming

# %%
#Print the string in reverse

# %%
print(SC3[::-1])
# Out:
# gnimmargorp nohtyP ot emoclew ,aleehS olleH

# %%
#Use slicing and print the word “Python” from the existing string.

# %%
print(SC3[25:31])
# Out:
# Python

# %%
#String Methods

# %%
#Convert the sentence to uppercase

# %%
string ="Python beginner tutorial"

# %%
print(string.upper())
# Out:
# PYTHON BEGINNER TUTORIAL

# %%
#Convert the sentence to lowercase

# %%
print(string.lower())
# Out:
# python beginner tutorial

# %%
#Use Capitalize and return the sentence to the original input form

# %%
print(string.capitalize())
# Out:
# Python beginner tutorial

# %%
#Count the total number of occurrences of character ‘t’ in the string

# %%
print(string.count("t"))
# Out:
# 3

# %%
#Replace Python by Machine Learning

# %% [markdown]
# print(string.replace("Python", "Machine Learning"))

# %%
#Tuples

# %%
T1 = (10,20,30)

# %%
T2 = (40,50,60)

# %%
t_combine = (T1+T2)

# %%
print(t_combine)
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
print(t_combine*3)
# Out:
# (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)

# %%
print(t_combine[2])
# Out:
# 30

# %%
print(t_combine[0:3])
# Out:
# (10, 20, 30)

# %%
print(t_combine[-3:])
# Out:
# (40, 50, 60)
